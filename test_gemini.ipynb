# %% [markdown]
# # Gemini API Model Listing
# This notebook lists all models available for your API key.

# %%
# !pip install -q -U google-genai

# %%
from google import genai
import os

# Your current key
GOOGLE_API_KEY = "AIzaSyCymFuXTHSBkuK64sAd8nLAjo2xmAB5Mzs"

client = genai.Client(api_key=GOOGLE_API_KEY)

try:
    print("Listing all available models for your API key...")
    for m in client.models.list():
        print(f"Model: {m.name}")
        print(f"  Supported Methods: {m.supported_methods}")
        print("-" * 30)
except Exception as e:
    print(f"\n❌ Error: {e}")
# Out:
# Listing all available models for your API key...
# Model: models/gemini-2.5-flash
#
# ❌ Error: 'Model' object has no attribute 'supported_methods'
